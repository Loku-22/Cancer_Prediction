# %% [markdown]
# ## Tech-stak
# * MLflow + Dagshub(Github):- Online monitoring (comet).
# * Minikube:- like kubernetes cluster on machine.
# * Kubeflow:- is like pipeline making.Works with only Kubernetes Clusters.
# * Use of DockerHub(Google registory container) like storing image.
# * Patience monitoring.
# * Resource Allocation.
# * Project setup-->Notebook->Data Processing-->Model-Training-->Data and code Versioning(GitHub)-->Experiment-racking-->User App Building-->Kubeflow setup-->Dockerization-->Pipeline making using Kubeflow-->Upload and running the pipeline.
# * Dockerization of the project like creating image.Pushing the docker file to dockerhub.Creates a Yaml file from Kubeflow upload uploads to dashboards.
# * PC--->Project Dockerize--->DockerHub(Image)--->Kubeflow--->Yaml--->Dashboards--->Run--->If Chnages required--->Executes in dockerhub as image (New image).we can use deployed image in GKE,DockerHub,VMinstances,Cloud Run,Amazon,Azure.
